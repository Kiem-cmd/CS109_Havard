# %%
import pandas as pd

# %% [markdown]
# For this exercise, we will working with StudentPerFormance dataset - infomation about exam score of high school students

# %%
df = pd.read_csv(r"C:\Users\ACER\Desktop\New folder\CS109_Havard\Lecture 2 Pandas and EDA\data\StudentsPerformance.csv")

# %%
df.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.shape
# Out:
# (1000, 8)

# %%
df['parental level of education'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
df['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
student_100_score_math = df[df['math score'] == 100]
student_100_score_math
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 149               completed         100            100             93
# 451                    none         100             92             97
# 458                    none         100            100            100
# 623               completed         100             96             86
# ...

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.describe(include=['object'])
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       518            319                         226       645
#
#        test preparation course
# count                     1000
# unique                       2
# top                       none
# freq                       642

# %%
cond1 = df['test preparation course'] != 'complete' 
cond2 = df['writing score'] > df['writing score'].median() 
uncomplete_with_good_writing_score = df.loc[cond1 & cond2]
uncomplete_with_good_writing_score
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# ### Sự khác biệt giữa loc() và iloc()

# %%
df.iloc[5,5] ## Trỏ đến tọa độ [5,5]
# Out:
# 71

# %%
df.index[5]
# Out:
# 5

# %%
df.loc[5]  ## Trỏ đến hàng có index là 5
# Out:
# gender                                     female
# race/ethnicity                            group B
# parental level of education    associate's degree
# lunch                                    standard
# test preparation course                      none
# math score                                     71
# reading score                                  83
# writing score                                  78
# Name: 5, dtype: object

# %% [markdown]
# ### Sorting

# %%
sorted_df = df.sort_values(by ='math score',ascending=True)
sorted_df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 787  female        group B                some college      standard
# 145  female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 625    male        group D                some college      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# 962  female        group E          associate's degree      standard
# 149    male        group E          associate's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# Sau khi đã sắp xếp lại theo điểm toán --> muốn tìm người xếp thứ 4 --> sử dụng loc

# %%
sorted_df.loc[4]
# Out:
# gender                                 male
# race/ethnicity                      group C
# parental level of education    some college
# lunch                              standard
# test preparation course                none
# math score                               76
# reading score                            78
# writing score                            75
# Name: 4, dtype: object

# %% [markdown]
# Muốn tìm người đứng thứ 4 theo danh sách ban đầu sử dụng iloc

# %%
sorted_df.iloc[4]
# Out:
# gender                               female
# race/ethnicity                      group C
# parental level of education    some college
# lunch                          free/reduced
# test preparation course                none
# math score                               22
# reading score                            39
# writing score                            33
# Name: 145, dtype: object

# %% [markdown]
# ### Columns Naming Conventions

# %% [markdown]
# * Cố gắng sử dụng tên cột ngắn
# * Tránh các kí tự như khoảng trắng
# * Nên viết chữ thường

# %%
df = df.rename(columns= {'race/ethnicity': 'race','parental level of education':'pedu','test preparation course':'course'})

# %%
df
# Out:
#      gender     race                pedu         lunch     course  math score  \
# 0    female  group B   bachelor's degree      standard       none          72
# 1    female  group C        some college      standard  completed          69
# 2    female  group B     master's degree      standard       none          90
# 3      male  group A  associate's degree  free/reduced       none          47
# 4      male  group C        some college      standard       none          76
# ..      ...      ...                 ...           ...        ...         ...
# 995  female  group E     master's degree      standard  completed          88
# 996    male  group C         high school  free/reduced       none          62
# 997  female  group C         high school  free/reduced  completed          59
# 998  female  group D        some college      standard  completed          68
# 999  female  group D        some college  free/reduced       none          77
#
# ...

# %% [markdown]
# ### Looking for missing values

# %%
df.iloc[0,5] = None 
df.iloc[2,2] = None

# %%
df.isna().head()
# Out:
#    gender   race   pedu  lunch  course  math score  reading score  \
# 0   False  False  False  False   False        True          False
# 1   False  False  False  False   False       False          False
# 2   False  False   True  False   False       False          False
# 3   False  False  False  False   False       False          False
# 4   False  False  False  False   False       False          False
#
#    writing score
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False

# %%
df.isna().sum()
# Out:
# gender           0
# race             0
# pedu             1
# lunch            0
# course           0
# math score       1
# reading score    0
# writing score    0
# dtype: int64

# %%
df['math score'] = df['math score'].fillna(df['math score'].mean())
df.head()
# Out:
#    gender     race                pedu         lunch     course  math score  \
# 0  female  group B   bachelor's degree      standard       none   66.083083
# 1  female  group C        some college      standard  completed   69.000000
# 2  female  group B                None      standard       none   90.000000
# 3    male  group A  associate's degree  free/reduced       none   47.000000
# 4    male  group C        some college      standard       none   76.000000
#
#    reading score  writing score
# 0             72             74
# 1             90             88
# 2             95             93
# 3             57             44
# 4             78             75

# %%
df = df.dropna()

# %% [markdown]
# Categorical Columns - unique() nunique()

# %%
df.nunique()
# Out:
# gender            2
# race              5
# pedu              6
# lunch             2
# course            2
# math score       82
# reading score    72
# writing score    77
# dtype: int64

# %%
df['gender'].unique().tolist()
# Out:
# ['female', 'male']

# %% [markdown]
# ### Describe()

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  999.000000     999.000000     999.000000
# mean    66.059142      69.143143      68.029029
# std     15.150597      14.584579      15.182727
# min      0.000000      17.000000      10.000000
# 25%     57.000000      59.000000      57.500000
# 50%     66.000000      70.000000      69.000000
# 75%     77.000000      79.000000      79.000000
# max    100.000000     100.000000     100.000000

# %%
df.describe(include=['object'])
# Out:
#         gender     race          pedu     lunch course
# count      999      999           999       999    999
# unique       2        5             6         2      2
# top     female  group C  some college  standard   none
# freq       517      319           226       644    641
